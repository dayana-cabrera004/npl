# %% [markdown]
# <a href="https://colab.research.google.com/github/dayana-cabrera004/npl/blob/main/Neural_Network_HWK.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('https://raw.githubusercontent.com/fenago/deep-learning-essentials/main/HeartDiseaseTrain-Test.csv')

# Display the first few rows of the dataset
#print(df.head())

# Display the column names
df.head()
# Out:
#    age     sex chest_pain_type  resting_blood_pressure  cholestoral  \
# 0   52    Male  Typical angina                     125          212
# 1   53    Male  Typical angina                     140          203
# 2   70    Male  Typical angina                     145          174
# 3   61    Male  Typical angina                     148          203
# 4   62  Female  Typical angina                     138          294
#
#       fasting_blood_sugar               rest_ecg  Max_heart_rate  \
# 0    Lower than 120 mg/ml  ST-T wave abnormality             168
# 1  Greater than 120 mg/ml                 Normal             155
# 2    Lower than 120 mg/ml  ST-T wave abnormality             125
# 3    Lower than 120 mg/ml  ST-T wave abnormality             161
# 4  Greater than 120 mg/ml  ST-T wave abnormality             106
#
#   exercise_induced_angina  oldpeak        slope vessels_colored_by_flourosopy  \
# 0                      No      1.0  Downsloping                           Two
# 1                     Yes      3.1    Upsloping                          Zero
# 2                     Yes      2.6    Upsloping                          Zero
# 3                      No      0.0  Downsloping                           One
# 4                      No      1.9         Flat                         Three
#
#          thalassemia  target
# 0  Reversable Defect       0
# 1  Reversable Defect       0
# 2  Reversable Defect       0
# 3  Reversable Defect       0
# 4       Fixed Defect       0

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Handle missing values if necessary
df = df.dropna()

# Separate input features and target variable
X = df.drop(columns=['target'])  # 'class' is your target column
y = df['target'].values

# Encode the categorical features in X
X = pd.get_dummies(X, drop_first=True)

# Encode the binary target variable y
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)  # use this for binary classification

n_features = X.shape[1]
# y will now be 0 for one class (e.g., 'good') and 1 for the other class (e.g., 'bad')

# %%
X.head()
# Out:
#    age  resting_blood_pressure  cholestoral  Max_heart_rate  oldpeak  \
# 0   52                     125          212             168      1.0
# 1   53                     140          203             155      3.1
# 2   70                     145          174             125      2.6
# 3   61                     148          203             161      0.0
# 4   62                     138          294             106      1.9
#
#    sex_Male  chest_pain_type_Atypical angina  \
# 0      True                            False
# 1      True                            False
# 2      True                            False
# 3      True                            False
# 4     False                            False
#
#    chest_pain_type_Non-anginal pain  chest_pain_type_Typical angina  \
# 0                             False                            True
# 1                             False                            True
# 2                             False                            True
# 3                             False                            True
# 4                             False                            True
#
#    fasting_blood_sugar_Lower than 120 mg/ml  ...  exercise_induced_angina_Yes  \
# 0                                      True  ...                        False
# 1                                     False  ...                         True
# 2                                      True  ...                         True
# 3                                      True  ...                        False
# 4                                     False  ...                        False
#
#    slope_Flat  slope_Upsloping  vessels_colored_by_flourosopy_One  \
# 0       False            False                              False
# 1       False             True                              False
# 2       False             True                              False
# 3       False            False                               True
# 4        True            False                              False
#
#    vessels_colored_by_flourosopy_Three  vessels_colored_by_flourosopy_Two  \
# 0                                False                               True
# 1                                False                              False
# 2                                False                              False
# 3                                False                              False
# 4                                 True                              False
#
#    vessels_colored_by_flourosopy_Zero  thalassemia_No  thalassemia_Normal  \
# 0                               False           False               False
# 1                                True           False               False
# 2                                True           False               False
# 3                               False           False               False
# 4                               False           False               False
#
#    thalassemia_Reversable Defect
# 0                           True
# 1                           True
# 2                           True
# 3                           True
# 4                          False
#
# [5 rows x 22 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Split into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# 1.Define the model
model = Sequential()
model.add(Dense(10, activation='relu', input_shape=(n_features,)))
model.add(Dense(8, activation='relu'))
#model.add(Dense(12, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# 2.Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.fit
150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8524 - loss: 0.3643
# Epoch 75/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8555 - loss: 0.3493
# Epoch 76/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8722 - loss: 0.3585
# Epoch 77/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8559 - loss: 0.3510
# Epoch 78/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8397 - loss: 0.3469
# Epoch 79/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8451 - loss: 0.3489
# Epoch 80/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8445 - loss: 0.3630
# Epoch 81/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8301 - loss: 0.3768
# Epoch 82/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8534 - loss: 0.3687
# Epoch 83/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8749 - loss: 0.3468
# Epoch 84/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8650 - loss: 0.3449
# Epoch 85/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8858 - loss: 0.3177
# Epoch 86/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8712 - loss: 0.3232
# Epoch 87/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8606 - loss: 0.3492
# Epoch 88/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8549 - loss: 0.3533
# Epoch 89/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8811 - loss: 0.3240
# Epoch 90/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.3284
# Epoch 91/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8623 - loss: 0.3427
# Epoch 92/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8619 - loss: 0.3216
# Epoch 93/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8625 - loss: 0.3513
# Epoch 94/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8478 - loss: 0.3446
# Epoch 95/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8720 - loss: 0.3325
# Epoch 96/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8589 - loss: 0.3213
# Epoch 97/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8368 - loss: 0.3748
# Epoch 98/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8603 - loss: 0.3414
# Epoch 99/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8689 - loss: 0.3386
# Epoch 100/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8329 - loss: 0.3571
# Epoch 101/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8626 - loss: 0.3551
# Epoch 102/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8601 - loss: 0.3329
# Epoch 103/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8879 - loss: 0.3289
# Epoch 104/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8707 - loss: 0.3280
# Epoch 105/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8205 - loss: 0.3606
# Epoch 106/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8552 - loss: 0.3563
# Epoch 107/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8659 - loss: 0.3365
# Epoch 108/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8470 - loss: 0.3678
# Epoch 109/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8701 - loss: 0.3168
# Epoch 110/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8464 - loss: 0.3338
# Epoch 111/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3271
# Epoch 112/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8402 - loss: 0.3499
# Epoch 113/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8642 - loss: 0.3346
# Epoch 114/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8606 - loss: 0.3521
# Epoch 115/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8700 - loss: 0.3221
# Epoch 116/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8493 - loss: 0.3508
# Epoch 117/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8622 - loss: 0.3377
# Epoch 118/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8652 - loss: 0.3269
# Epoch 119/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8677 - loss: 0.3210
# Epoch 120/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8636 - loss: 0.3097
# Epoch 121/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8788 - loss: 0.3099
# Epoch 122/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8705 - loss: 0.3387
# Epoch 123/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8877 - loss: 0.3244
# Epoch 124/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8554 - loss: 0.3569
# Epoch 125/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8580 - loss: 0.3584
# Epoch 126/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9011 - loss: 0.2845
# Epoch 127/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8739 - loss: 0.3225
# Epoch 128/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8601 - loss: 0.3492
# Epoch 129/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8632 - loss: 0.3340
# Epoch 130/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8614 - loss: 0.3452
# Epoch 131/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8886 - loss: 0.3214
# Epoch 132/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8861 - loss: 0.3317
# Epoch 133/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8811 - loss: 0.3248
# Epoch 134/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8439 - loss: 0.3382
# Epoch 135/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8677 - loss: 0.3211
# Epoch 136/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8817 - loss: 0.3072
# Epoch 137/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8644 - loss: 0.3324
# Epoch 138/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8496 - loss: 0.3055
# Epoch 139/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8619 - loss: 0.3417
# Epoch 140/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8617 - loss: 0.3227
# Epoch 141/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8876 - loss: 0.3330
# Epoch 142/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8858 - loss: 0.3061
# Epoch 143/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8627 - loss: 0.3383
# Epoch 144/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8360 - loss: 0.3589
# Epoch 145/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8545 - loss: 0.3466
# Epoch 146/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8961 - loss: 0.2958
# Epoch 147/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8531 - loss: 0.3460
# Epoch 148/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8836 - loss: 0.3195
# Epoch 149/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8956 - loss: 0.2938
# Epoch 150/150
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9016 - loss: 0.2683

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print('Test Accuracy: %.3f' % acc)
# Out:
# Test Accuracy: 0.853

# %%
row = [your_row_of_data_here] # or copy a row from your existing data and modify
yhat = model.predict([row])
print('Predicted: %.3f' % yhat)
